# %% [markdown]
# # SOSE Surface Forcing

# %% [markdown]
# 5-year average (2008-2012) of surface wind stresses, heat and freshwater fluxes that are used in SOSE dataset are plotted. These are used for preparation of zonally uniform forcing profiles for running idealized high-resolution simulations to study the Southern Ocean dynamics using MOM6 model.

# %%
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import numpy as np
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import glob, os

# %%
# Read files
ppdir = "/Volumes/Seagate_Hemant2/Work/Ocean/2019_SOSE/Dataset/"
ds = xr.open_mfdataset(ppdir + "*2008to2012.nc")

print(ds)
# Out:
# <xarray.Dataset>
# Dimensions:   (XC: 1080, XG: 1080, YC: 294, YG: 294, time: 118)
# Coordinates:
#   * time      (time) datetime64[ns] 2008-01-31T10:00:00 ... 2012-12-30T12:00:00
#     iter      (time) float64 dask.array<chunksize=(118,), meta=np.ndarray>
#   * XC        (XC) float32 0.16666667 0.5 0.8333333 ... 359.5 359.83334
#   * YC        (YC) float32 -77.96525 -77.89555 ... -30.089203 -29.789328
#     Depth     (YC, XC) float32 dask.array<chunksize=(294, 1080), meta=np.ndarray>
#     rA        (YC, XC) float32 dask.array<chunksize=(294, 1080), meta=np.ndarray>
#   * XG        (XG) float32 0.0 0.33333334 0.6666667 ... 359.33334 359.66666
#     dxC       (YC, XG) float32 dask.array<chunksize=(294, 1080), meta=np.ndarray>
#     rAw       (YC, XG) float32 dask.array<chunksize=(294, 1080), meta=np.ndarray>
#     dyG       (YC, XG) float32 dask.array<chunksize=(294, 1080), meta=np.ndarray>
#   * YG        (YG) float32 -78.0 -77.9305 -77.8606 ... -30.233406 -29.944998
#     rAs       (YG, XC) float32 dask.array<chunksize=(294, 1080), meta=np.ndarray>
#     dxG       (YG, XC) float32 dask.array<chunksize=(294, 1080), meta=np.ndarray>
#     dyC       (YG, XC) float32 dask.array<chunksize=(294, 1080), meta=np.ndarray>
# Data variables:
#     SFLUX     (time, YC, XC) float32 dask.array<chunksize=(118, 294, 1080), meta=np.ndarray>
#     SIatmFW   (time, YC, XC) float32 dask.array<chunksize=(118, 294, 1080), meta=np.ndarray>
#     SIempmr   (time, YC, XC) float32 dask.array<chunksize=(118, 294, 1080), meta=np.ndarray>
#     SIsnPrcp  (time, YC, XC) float32 dask.array<chunksize=(118, 294, 1080), meta=np.ndarray>
#     TFLUX     (time, YC, XC) float32 dask.array<chunksize=(118, 294, 1080), meta=np.ndarray>
#     oceTAUX   (time, YC, XG) float32 dask.array<chunksize=(118, 294, 1080), meta=np.ndarray>
#     oceTAUY   (time, YG, XC) float32 dask.array<chunksize=(118, 294, 1080), meta=np.ndarray>

# %%
def SOSE_plot_mono(ax, da, vmin=-999, vmax=999, vstep=1,
                        lon='XC', lat='YC', landcolor=1.,
                        cmap='RdBu_r', title='what is it?'):
    """ standard global plot for the Southern Ocean """

    from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER 
    
    #fig = plt.figure(figsize=[16,10])
    #ax = plt.axes(projection=ccrs.PlateCarree())
    ax.coastlines()
    #ax.add_feature(cfeature.LAND)
    ax.set_extent([-180, 180, -75, -28], crs=ccrs.PlateCarree())
    #ax.set_xticks([0, 60, 120, 180, 240, 300, 360], crs=ccrs.PlateCarree())
    #ax.set_yticks([-70, -60, -50, -40, -30], crs=ccrs.PlateCarree())
    #lon_formatter = LONGITUDE_FORMATTER
    #lat_formatter = LATITUDE_FORMATTER 
    #ax.xaxis.set_major_formatter(lon_formatter)
    #ax.yaxis.set_major_formatter(lat_formatter)

    # parallels/meridiens
    gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                      linewidth=2, color='gray', alpha=0.5, linestyle='--')
    gl.xlabels_top = False
    gl.ylabels_right = False
    gl.ylocator = mticker.FixedLocator([-80, -70, -60, -50, -40, -30])
    gl.xformatter = LONGITUDE_FORMATTER
    gl.yformatter = LATITUDE_FORMATTER
    gl.xlabel_style = {'size': 12, 'color': 'black'}
    gl.ylabel_style = {'size': 12, 'color': 'black'}

    # contours
    contours = np.arange(vmin, vmax+vstep, vstep)

    cf = da.plot.contourf(ax=ax, transform=ccrs.PlateCarree(),
                          x=lon, y=lat,
                          levels=contours,
                          vmin=vmin, vmax=vmax,
                          add_labels=False,
                          add_colorbar=False,
                          cmap=cmap)
    # add separate colorbar
    cb = plt.colorbar(cf, ax=ax, format='%.0e', extend='both', shrink=0.9)
    cb.ax.tick_params(labelsize=12)
    #cb.formatter.set_scientific(True)
    #cb.formatter.set_powerlimits((-1, 1))
    
    #ax.set_adjustable('datalim')

    """
    # create a land 'topo' array with uniform value (0 < landcolor < 2)
    topo = xr.DataArray(data=landcolor * np.ones(da.shape), dims=da.dims)
    # make it exist only when ocean data is nan
    topo = topo.where(np.isnan(da))
    # assign true coords
    topo = topo.assign_coords({'geolon': da['XC'],
                               'geolat': da['YC']})
    # plot
    _ = topo.plot.pcolormesh(ax=ax, transform=ccrs.PlateCarree(),
                             x=lon, y=lat, cmap='binary',
                             vmin=0, vmax=2, add_labels=False,
                             add_colorbar=False)

    """
    
    ax.set_aspect(1.3)

    # title
    _ = plt.title(title, fontsize=16)
    return fig

# %%
grid = plt.GridSpec(6, 4, wspace=0.4, hspace=0.3)

fig = plt.figure(figsize=[18,18])
ax = fig.add_subplot(grid[0, 0:], projection=ccrs.PlateCarree())
_ = SOSE_plot_mono(ax, ds['oceTAUX'].mean('time'), vmin=-0.25, vmax=0.25, vstep=0.025,
                   lon='XG', lat='YC', landcolor=2., cmap='RdBu_r', title='Zonal Wind Stress (N/m$^2$)')

ax = fig.add_subplot(grid[1, 0:], projection=ccrs.PlateCarree())
_ = SOSE_plot_mono(ax, ds['oceTAUY'].mean('time'), vmin=-0.15, vmax=0.15, vstep=0.025,
                   lon='XC', lat='YG', landcolor=2., cmap='RdBu_r', title='Meridional Wind Stress (N/m$^2$)')

ax = fig.add_subplot(grid[2, 0:], projection=ccrs.PlateCarree())
_ = SOSE_plot_mono(ax, (ds['TFLUX']*ds['Depth']/ds['Depth']).mean('time'), vmin=-100, vmax=100, vstep=20,
                   lon='XC', lat='YC', landcolor=2., cmap='RdBu_r', title='Surface Heat Flux (W/m$^2$)')

ax = fig.add_subplot(grid[3, 0:], projection=ccrs.PlateCarree())
_ = SOSE_plot_mono(ax, ds['SIatmFW'].mean('time'), vmin=-1e-4, vmax=1e-4, vstep=1e-5,
                   lon='XC', lat='YC', landcolor=2., cmap='RdBu_r', title='Fresh Water Flux (kg/m$^2$s)')

ax = fig.add_subplot(grid[4, 0:], projection=ccrs.PlateCarree())
_ = SOSE_plot_mono(ax, ds['SIsnPrcp'].mean('time'), vmin=-3e-5, vmax=3e-5, vstep=0.5e-5,
                   lon='XC', lat='YC', landcolor=2., cmap='RdBu_r', title='Fresh Water Flux (kg/m$^2$s)')

ax = fig.add_subplot(grid[5, 0])
ax.plot(ds['oceTAUX'].sel(XG = slice(30,110)).mean(['time','XG']),ds['YC'],lw=2, label='Zonal')
ax.plot(ds['oceTAUY'].sel(XC = slice(30,110)).mean(['time','XC']),ds['YG'],lw=2, label='Meridional')
ax.set_xlabel('Wind Stress (N/m$^2$)',fontsize=14)
plt.yticks([-70, -60, -50, -40, -30], 
           ['70$^{\circ}$S', '60$^{\circ}$S', '50$^{\circ}$S', '40$^{\circ}$S', '30$^{\circ}$S'],fontsize=12)
ax.set_ylim([-75,-28])
plt.xticks(fontsize=12)
ax.axvline(x=0, lw=1, ls='--')
plt.grid()
ax.legend(loc='upper center', bbox_to_anchor=(0.9, 0.45), fontsize=14)

ax = fig.add_subplot(grid[5, 1])
ax.plot((ds['TFLUX']*ds['Depth']/ds['Depth']).sel(XC = slice(30,110)).mean(['time','XC']),ds['YC'],lw=2)
ax.set_xlabel('Heat Flux (W/m$^2$)',fontsize=14)
plt.yticks([-70, -60, -50, -40, -30], 
           ['70$^{\circ}$S', '60$^{\circ}$S', '50$^{\circ}$S', '40$^{\circ}$S', '30$^{\circ}$S'],fontsize=12)
ax.set_ylim([-75,-28])
plt.xticks(fontsize=12)
plt.grid()
ax.axvline(x=0, lw=1, ls='--')

ax = fig.add_subplot(grid[5, 2])
ax.plot(ds['SIatmFW'].sel(XC = slice(30,110)).mean(['time','XC']),ds['YC'],lw=2, label='FW Flux')
ax.plot(ds['SIsnPrcp'].sel(XC = slice(30,110)).mean(['time','XC']),ds['YC'],lw=2, label='Snow Flux')
ax.set_xlabel('Flux (kg/m$^2$s)',fontsize=14)
plt.yticks([-70, -60, -50, -40, -30], 
           ['70$^{\circ}$S', '60$^{\circ}$S', '50$^{\circ}$S', '40$^{\circ}$S', '30$^{\circ}$S'],fontsize=12)
ax.set_ylim([-75,-28])
plt.xticks([-2e-5, -1e-5, 0, 1e-5, 2e-5], ['-2e-5', '-1e-5', '0', '1e-5','2e-5'],fontsize=12)
ax.axvline(x=0, lw=1, ls='--')
plt.grid()
ax.legend(loc='upper center', bbox_to_anchor=(1.0, 1.0), fontsize=14)

# %%
plt.figure(figsize=[18,3])
ds.Depth.plot()

# %%
# Temperature data between 2013-2017
ds_T = xr.open_dataset(ppdir+"bsose_i122_2013to2017_monthly_Theta.nc")
ds_T
# Out:
# <xarray.Dataset>
# Dimensions:  (XC: 2160, YC: 588, Z: 52, time: 60)
# Coordinates:
#     iter     (time) int64 ...
#   * time     (time) datetime64[ns] 2013-01-30T20:48:00 ... 2017-12-31T10:24:00
#   * XC       (XC) float32 0.083333336 0.25 0.4166667 ... 359.75 359.9167
#   * YC       (YC) float32 -77.98265 -77.9479 -77.91305 ... -29.870987 -29.715317
#   * Z        (Z) float32 -2.1 -6.7 -12.15 -18.55 ... -5000.0 -5400.0 -5800.0
#     Depth    (YC, XC) float32 ...
#     rA       (YC, XC) float32 ...
#     drF      (Z) float32 ...
#     hFacC    (Z, YC, XC) float32 ...
# Data variables:
#     THETA    (time, Z, YC, XC) float32 ...

# %%
fig = plt.figure(figsize=[18,6])

grid = plt.GridSpec(2, 3, wspace=0.4, hspace=0.3)

ax = fig.add_subplot(grid[0, 0:])
ds_T['THETA'].isel(Z=0).mean('time').plot()
plt.grid()

ax = fig.add_subplot(grid[1, 0])
ax.plot(ds_T['THETA'].isel(Z=0).sel(XC = slice(30,110)).mean(['time','XC']),ds_T['YC'],lw=2)
plt.grid()
plt.yticks([-70, -60, -50, -40, -30], 
           ['70$^{\circ}$S', '60$^{\circ}$S', '50$^{\circ}$S', '40$^{\circ}$S', '30$^{\circ}$S'],fontsize=12)
ax.set_ylim([-75,-28])
ax.set_xlabel('Temperature (Deg C)',fontsize=14)
ax.set_ylabel('Latitude',fontsize=14)

ax = fig.add_subplot(grid[1, 1])
ax.plot(ds_T['THETA'].sel(XC = slice(30,110), YC=slice(-32,-30)).mean(['time','XC','YC']),ds_T['Z'],lw=2)
plt.grid()
ax.set_xlabel('Temperature (Deg C)',fontsize=14)
ax.set_ylabel('Depth (m)',fontsize=14)
# Out:
# Text(0, 0.5, 'Depth (m)')

# %% [markdown]
# # Fit analyic functions to profiles

# %%
import initialization_functions as infs

X,Y = infs.calc_XYmeters_SOSE(ds.sel(XC = slice(30,110), XG = slice(30,109.9)),center_x = True)

# %%
print(Y)
Y.plot()
# Out:
# <xarray.DataArray (lath: 294, lonh: 240)>
# array([[3.86347290e+03, 3.86347290e+03, 3.86347290e+03, ...,
#         3.86347290e+03, 3.86347290e+03, 3.86347290e+03],
#        [1.16124875e+04, 1.16124875e+04, 1.16124875e+04, ...,
#         1.16124875e+04, 1.16124875e+04, 1.16124875e+04],
#        [1.94057510e+04, 1.94057510e+04, 1.94057510e+04, ...,
#         1.94057510e+04, 1.94057510e+04, 1.94057510e+04],
#        ...,
#        [5.29458475e+06, 5.29458475e+06, 5.29458475e+06, ...,
#         5.29458475e+06, 5.29458475e+06, 5.29458475e+06],
#        [5.32660275e+06, 5.32660275e+06, 5.32660275e+06, ...,
#         5.32660275e+06, 5.32660275e+06, 5.32660275e+06],
#        [5.35994200e+06, 5.35994200e+06, 5.35994200e+06, ...,
#         5.35994200e+06, 5.35994200e+06, 5.35994200e+06]])
# Coordinates:
#   * lath     (lath) float32 -77.96525 -77.89555 ... -30.089203 -29.789328
#   * lonh     (lonh) float32 30.166666 30.5 30.833334 ... 109.5 109.833336

# %%
# Vertical grid
nk = 75
max_depth = 4000.
min_depth = 0.
thkcello_topcell = 1.
method = 'powerlaw'

vgrid = infs.calc_vgrid(nk=nk,max_depth=max_depth,min_depth=min_depth,
                        thkcello_topcell=thkcello_topcell,method=method)

# %%
print(vgrid)
plt.plot(vgrid['dz'])
# Out:
# <xarray.Dataset>
# Dimensions:  (NK: 75, NKp1: 76)
# Coordinates:
#   * NKp1     (NKp1) float64 0.0 1.0 3.787 8.252 ... 3.798e+03 3.898e+03 4e+03
#   * NK       (NK) float64 0.5 2.393 6.02 11.3 ... 3.748e+03 3.848e+03 3.949e+03
# Data variables:
#     zw       (NKp1) float64 0.0 1.0 3.787 8.252 ... 3.798e+03 3.898e+03 4e+03
#     zt       (NK) float64 0.5 2.393 6.02 11.3 ... 3.748e+03 3.848e+03 3.949e+03
#     dz       (NK) float64 1.0 2.787 4.465 6.089 ... 98.04 99.31 100.6 101.8

# %%
# Wind forcing

sponge_width = [2.,1.]

taux_east = 0.18
taux_west = 0.08
Y0 = Y.isel(lonh =0, lath = np.abs(ds.YC.values + 63.0).argmin()).values # Boundary between ACC/ASF
Lc = Y.isel(lonh =0, lath = np.abs(ds.YC.values + 69.0).argmin()).values # South Zero
sp_wid = np.max(Y.isel(lonh=0).values) - Y.isel(lonh =0, lath = np.abs(ds.YC.values - np.max(Y.lath.values) + 2.).argmin()).values

wind = xr.Dataset()
wind['taux'] = infs.calc_forcing_zonaluniform(Y,function='doublesinusoid_squared',
                                 sponge_width_max = sp_wid,
                                 northsouth_boundary = Y0,
                                 south_zeroregion = Lc, 
                                 max_north = taux_east, 
                                 max_south = taux_west)

wind['taux_skew'] = infs.calc_forcing_zonaluniform(Y,function='doublesinusoid_skew',
                                 sponge_width_max = sp_wid,
                                 northsouth_boundary = Y0,
                                 south_zeroregion = Lc, 
                                 max_north = taux_east, 
                                 max_south = taux_west, alpha = 0.8)

wind['taux_skew2'] = infs.calc_forcing_zonaluniform(Y,function='doublesinusoid_mix_skew',
                                 sponge_width_max = sp_wid,
                                 northsouth_boundary = Y0,
                                 south_zeroregion = Lc, 
                                 max_north = taux_east, 
                                 max_south = taux_west, alpha = 0.9)

# %%
plt.plot(ds['oceTAUX'].sel(XG = slice(30,110)).mean(['time','XG']),ds['YC'],'--',lw=2, label='SOSE')
#plt.plot(wind['taux'].isel(lonh=0), wind['lath'],label = 'Sin Square')
plt.plot(wind['taux_skew'].isel(lonh=0), wind['lath'],label = 'Analytic Skew')
plt.grid()
plt.xlabel('Zonal Wind Stress (N/m$^2$)')
plt.legend()

# %%
# Buoyancy forcing

Buo_east = 25. # W/m^2
Buo_west = 18.
Y0 = Y.isel(lonh =0, lath = np.abs(ds.YC.values + 58.0).argmin()).values # Boundary between ACC/ASF
Lc = Y.isel(lonh =0, lath = np.abs(ds.YC.values + 69.0).argmin()).values # South Zero
sp_wid = np.max(Y.isel(lonh=0).values) - Y.isel(lonh =0, lath = np.abs(ds.YC.values - np.max(Y.lath.values) + 2.).argmin()).values

buoyancy = xr.Dataset()
buoyancy['sensible'] = infs.calc_forcing_zonaluniform(Y,function='doublesinusoid_skew',
                                 sponge_width_max = sp_wid,
                                 northsouth_boundary = Y0,
                                 south_zeroregion = Lc, 
                                 max_north = Buo_east, 
                                 max_south = Buo_west, alpha = 0.0)

buoyancy['sensible_skew'] = infs.calc_forcing_zonaluniform(Y,function='doublesinusoid_skew',
                                 sponge_width_max = sp_wid,
                                 northsouth_boundary = Y0,
                                 south_zeroregion = Lc, 
                                 max_north = Buo_east, 
                                 max_south = Buo_west, alpha = 1.5)

# %%
# Fresh water flux and snow flux
Buo_east = -2.5e-5 # kg/m^2s
Buo_west = -1.8e-5
Y0 = Y.isel(lonh =0, lath = np.abs(ds.YC.values + 49.0).argmin()).values # Boundary between ACC/ASF
Lc = Y.isel(lonh =0, lath = np.abs(ds.YC.values + 69.0).argmin()).values # South Zero
sp_wid = np.max(Y.isel(lonh=0).values) - Y.isel(lonh =0, lath = np.abs(ds.YC.values - np.max(Y.lath.values) + 2.).argmin()).values
buoyancy['FW'] = infs.calc_forcing_zonaluniform(Y,function='doublesinusoid_gen',
                                 sponge_width_max = sp_wid,
                                 northsouth_boundary = Y0,
                                 south_zeroregion = Lc, 
                                 max_north = Buo_east, 
                                 max_south = Buo_west, a=2., b=1., c=1., d=2., e=1., f=1.)

Buo_east = -0.e-5 # kg/m^2s
Buo_west = -1.21e-5
Y0 = Y.isel(lonh =0, lath = np.abs(ds.YC.values + 55.0).argmin()).values # Boundary between ACC/ASF
Lc = Y.isel(lonh =0, lath = np.abs(ds.YC.values + 70.0).argmin()).values # South Zero
sp_wid = np.max(Y.isel(lonh=0).values) - Y.isel(lonh =0, lath = np.abs(ds.YC.values - np.max(Y.lath.values) + 2.).argmin()).values
buoyancy['Snow'] = infs.calc_forcing_zonaluniform(Y,function='doublesinusoid_gen',
                                 sponge_width_max = sp_wid,
                                 northsouth_boundary = Y0,
                                 south_zeroregion = Lc, 
                                 max_north = Buo_east, 
                                 max_south = Buo_west, a=1., b=1., c=1., d=1., e=0.9, f=2.)

# %%
fig = plt.figure(figsize=[15,4])

plt.subplot(1,3,1)
plt.plot((ds['TFLUX']*ds['Depth']/ds['Depth']).sel(XC = slice(30,110)).mean(['time','XC']),ds['YC'],'--',lw=2, label='SOSE')
plt.plot(buoyancy['sensible'].isel(lonh=0), buoyancy['lath'],label = 'Analytic Symm')
plt.plot(buoyancy['sensible_skew'].isel(lonh=0), buoyancy['lath'],label = 'Analytic Skew')
plt.legend()
plt.xlabel('Heat Flux (W/m$^2$)')
plt.grid()

plt.subplot(1,3,2)
plt.plot((ds['SIatmFW']).sel(XC = slice(30,110)).mean(['time','XC']),ds['YC'],lw=2, label='SOSE')
plt.plot(buoyancy['FW'].isel(lonh=0), buoyancy['lath'],label = 'Analytic')
plt.legend()
plt.xticks([-2e-5, -1e-5, 0, 1e-5, 2e-5], ['-2e-5', '-1e-5', '0', '1e-5','2e-5'])
plt.xlabel('Fresh Water Flux (kg/m$^2$s)')
plt.grid()

plt.subplot(1,3,3)
plt.plot((ds['SIsnPrcp']).sel(XC = slice(30,110)).mean(['time','XC']),ds['YC'],lw=2, label='SOSE')
plt.plot(buoyancy['Snow'].isel(lonh=0), buoyancy['lath'],label = 'Analytic')
plt.xticks([-2e-5, -1e-5, 0, 1e-5, 2e-5], ['-2e-5', '-1e-5', '0', '1e-5','2e-5'])
plt.legend()
plt.xlabel('Snow Flux (kg/m$^2$s)')
plt.grid()

# %%
# Temperature and salinity initial conditions
Tn = 10
Ts = 0

TS = xr.Dataset()
TS['SST'] = infs.calc_distribution(coordinate = Y, function='linear', val_at_maxcoord = Tn, val_at_mincoord = Ts)

# Extend temperature and salinity in the vertical
TS['T'] = infs.calc_distribution(coordinate=-vgrid.zt, function = 'exponential', val_at_maxcoord = TS['SST'], efolding = 800)
TS['S'] = infs.calc_distribution(coordinate=-vgrid.zt, function = 'linear', val_at_maxcoord = TS['SSS'], val_at_mincoord = TS['SSS'])

# %%
"""
fig = plt.figure(figsize=[16,10])
plt.subplot(3,1,1)
ds['oceTAUX'].mean('time').plot(vmin=-0.25, vmax=0.25, extend='both',cmap = 'RdBu_r');

plt.subplot(3,1,2)
ds['oceTAUY'].mean('time').plot();

plt.subplot(3,1,3)
(ds['TFLUX']*ds['Depth']/ds['Depth']).mean('time').plot(vmin=-100, vmax=100, extend='both',cmap = 'RdBu_r');
"""
# Out:
# "\nfig = plt.figure(figsize=[16,10])\nplt.subplot(3,1,1)\nds['oceTAUX'].mean('time').plot(vmin=-0.25, vmax=0.25, extend='both',cmap = 'RdBu_r');\n\nplt.subplot(3,1,2)\nds['oceTAUY'].mean('time').plot();\n\nplt.subplot(3,1,3)\n(ds['TFLUX']*ds['Depth']/ds['Depth']).mean('time').plot(vmin=-100, vmax=100, extend='both',cmap = 'RdBu_r');\n"

# %%
"""
fig = plt.figure(figsize=[16,10])
plt.subplot(4,1,1)
(ds['SIatmFW']).mean('time').plot(vmin=-1e-4, vmax=1e-4, extend='both',cmap = 'RdBu_r');

plt.subplot(4,1,2)
ds['SIsnPrcp'].mean('time').plot();

plt.subplot(4,1,3)
(ds['SIempmr']).mean('time').plot(vmin=-1e-4, vmax=1e-4, extend='both',cmap = 'RdBu_r');

plt.subplot(4,1,4)
ds['SFLUX'].mean('time').plot(vmin=-5e-3, vmax=5e-3, extend='both',cmap = 'RdBu_r');
"""
# Out:
# "\nfig = plt.figure(figsize=[16,10])\nplt.subplot(4,1,1)\n(ds['SIatmFW']).mean('time').plot(vmin=-1e-4, vmax=1e-4, extend='both',cmap = 'RdBu_r');\n\nplt.subplot(4,1,2)\nds['SIsnPrcp'].mean('time').plot();\n\nplt.subplot(4,1,3)\n(ds['SIempmr']).mean('time').plot(vmin=-1e-4, vmax=1e-4, extend='both',cmap = 'RdBu_r');\n\nplt.subplot(4,1,4)\nds['SFLUX'].mean('time').plot(vmin=-5e-3, vmax=5e-3, extend='both',cmap = 'RdBu_r');\n"

# %%
ds.close()
ds_T.close()
