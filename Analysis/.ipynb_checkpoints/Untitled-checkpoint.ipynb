# %% [markdown]
# $\Large \text{Testing 1/4 degree simulation}$
#
# The test run was forced with analytical wind stress, surface heat flux and freshwater forcing. The run used EOS from Wright et al. (1997).

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import xarray as xr
from xgcm import Grid
import dask 
import dask.distributed
# %matplotlib inline

# %%
from dask.distributed import Client
from dask.distributed import LocalCluster
cluster = LocalCluster()
client = Client(cluster)
client
# Out:
# /home/Hemant.Khatri/anaconda3/envs/analysis_python3/lib/python3.7/site-packages/distributed/dashboard/core.py:72: UserWarning:
# Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the diagnostics dashboard on a random port instead.
#   warnings.warn("\n" + msg)
# <Client: 'tcp://127.0.0.1:33971' processes=4 threads=16, memory=406.01 GB>

# %% [markdown]
# $\large \text{Stats time series}$

# %%
ppdir = "/work/Hemant.Khatri/MOM6_idealised/PEM_ACC/N_75/Z_star//TS_Wright/"
ds_stat = xr.open_mfdataset(ppdir+"ocean.stats*.nc")
print(ds_stat)

ds_n = xr.open_mfdataset(ppdir+"prog_n*.nc",decode_times=False)
print(ds_n)
# Out:
# /home/Hemant.Khatri/anaconda3/envs/analysis_python3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: In xarray version 0.14 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#
# /home/Hemant.Khatri/anaconda3/envs/analysis_python3/lib/python3.7/site-packages/xarray/backends/api.py:934: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# <xarray.Dataset>
# Dimensions:        (Interface: 76, Layer: 75, Time: 732)
# Coordinates:
#   * Interface      (Interface) float64 0.0 1.0 3.787 ... 3.898e+03 4e+03
#   * Layer          (Layer) float64 0.5 2.393 6.02 ... 3.848e+03 3.949e+03
#   * Time           (Time) timedelta64[ns] 0 days 10 days ... 7290 days 7300 days
# Data variables:
#     Ntrunc         (Time) float64 dask.array<chunksize=(366,), meta=np.ndarray>
#     En             (Time) float64 dask.array<chunksize=(366,), meta=np.ndarray>
#     APE            (Time, Interface) float64 dask.array<chunksize=(366, 76), meta=np.ndarray>
#     KE             (Time, Layer) float64 dask.array<chunksize=(366, 75), meta=np.ndarray>
#     H0             (Time, Interface) float64 dask.array<chunksize=(366, 76), meta=np.ndarray>
#     Mass_lay       (Time, Layer) float64 dask.array<chunksize=(366, 75), meta=np.ndarray>
#     Mass           (Time) float64 dask.array<chunksize=(366,), meta=np.ndarray>
#     Mass_chg       (Time) float64 dask.array<chunksize=(366,), meta=np.ndarray>
#     Mass_anom      (Time) float64 dask.array<chunksize=(366,), meta=np.ndarray>
#     max_CFL_trans  (Time) float64 dask.array<chunksize=(366,), meta=np.ndarray>
#     max_CFL_lin    (Time) float64 dask.array<chunksize=(366,), meta=np.ndarray>
#     Salt           (Time) float64 dask.array<chunksize=(366,), meta=np.ndarray>
#     Salt_chg       (Time) float64 dask.array<chunksize=(366,), meta=np.ndarray>
#     Salt_anom      (Time) float64 dask.array<chunksize=(366,), meta=np.ndarray>
#     Heat           (Time) float64 dask.array<chunksize=(366,), meta=np.ndarray>
#     Heat_chg       (Time) float64 dask.array<chunksize=(366,), meta=np.ndarray>
#     Heat_anom      (Time) float64 dask.array<chunksize=(366,), meta=np.ndarray>
# Attributes:
#     filename:  ./ocean.stats.nc
# <xarray.Dataset>
# Dimensions:      (Time: 242, nv: 2, scalar_axis: 1, xh: 320, yh: 272)
# Coordinates:
#   * xh           (xh) float64 0.125 0.375 0.625 0.875 ... 79.38 79.62 79.88
#   * scalar_axis  (scalar_axis) float64 0.0
#   * yh           (yh) float64 -69.94 -69.85 -69.77 ... -30.46 -30.24 -30.02
#   * nv           (nv) float64 1.0 2.0
#   * Time         (Time) float64 15.0 45.0 75.0 ... 7.205e+03 7.235e+03 7.265e+03
# Data variables:
#     SSH          (Time, yh, xh) float32 dask.array<chunksize=(121, 272, 320), meta=np.ndarray>
#     thetaoga     (Time, scalar_axis) float32 dask.array<chunksize=(121, 1), meta=np.ndarray>
#     soga         (Time, scalar_axis) float32 dask.array<chunksize=(121, 1), meta=np.ndarray>
#     average_T1   (Time) float64 dask.array<chunksize=(121,), meta=np.ndarray>
#     average_T2   (Time) float64 dask.array<chunksize=(121,), meta=np.ndarray>
#     average_DT   (Time) float64 dask.array<chunksize=(121,), meta=np.ndarray>
#     Time_bnds    (Time, nv) float64 dask.array<chunksize=(121, 2), meta=np.ndarray>
# Attributes:
#     filename:          prog.nc
#     title:             channel_4th-deg
#     associated_files:  area_t: grid.nc
#     grid_type:         regular
#     grid_tile:         N/A
# /home/Hemant.Khatri/anaconda3/envs/analysis_python3/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: In xarray version 0.14 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   """
# /home/Hemant.Khatri/anaconda3/envs/analysis_python3/lib/python3.7/site-packages/xarray/backends/api.py:934: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,

# %%
plt.figure(figsize=(16,6))

plt.subplot(2,2,1)
plt.plot(ds_stat['Time']/(24*3600*1e9), ds_stat['En'])
plt.grid()
plt.xlabel('Time (day)')
plt.ylabel('Total Energy (J)')

plt.subplot(2,2,2)
plt.plot(ds_stat['Time']/(1e9*3600*24), ds_stat['Mass'])
plt.grid()
plt.xlabel('Time (day)')
plt.ylabel('Total Mass (kg)')

plt.subplot(2,2,3)
plt.plot(ds_stat['Time']/(1e9*3600*24), ds_stat['Heat'])
plt.grid()
plt.xlabel('Time (day)')
plt.ylabel('Total Heat (J)')

plt.subplot(2,2,4)
plt.plot(ds_stat['Time']/(1e9*3600*24), ds_stat['Salt'])
plt.grid()
plt.xlabel('Time (day)')
plt.ylabel('Total Salt (kg)')
# Out:
# Text(0, 0.5, 'Total Salt (kg)')

# %%
plt.figure(figsize=(16,4))

plt.subplot(1,2,1)
plt.plot(ds_n['Time'], ds_n['thetaoga'])
plt.grid()
plt.xlabel('Time (day)')
plt.ylabel('Domain Mean Temperature (Deg C)')

plt.subplot(1,2,2)
plt.plot(ds_n['Time'], ds_n['soga'])
plt.grid()
plt.xlabel('Time (day)')
plt.ylabel('Domain Mean Salinity (psu)')
# Out:
# Text(0, 0.5, 'Domain Mean Salinity (psu)')

# %%
ds_n.close()
ds_stat.close()

# %% [markdown]
# $\large \text{Spatial fields}$

# %%
ds_z = xr.open_mfdataset(ppdir+"prog_z*.nc",decode_times=False)
print(ds_z)

ds_rho = xr.open_mfdataset(ppdir+"prog_rho2*.nc",decode_times=False)
print(ds_rho)
# Out:
# /home/Hemant.Khatri/anaconda3/envs/analysis_python3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: In xarray version 0.14 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   """Entry point for launching an IPython kernel.
# /home/Hemant.Khatri/anaconda3/envs/analysis_python3/lib/python3.7/site-packages/xarray/backends/api.py:934: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# <xarray.Dataset>
# Dimensions:     (Time: 20, nv: 2, xh: 320, xq: 320, yh: 272, yq: 272, z_i: 76, z_l: 75)
# Coordinates:
#   * xh          (xh) float64 0.125 0.375 0.625 0.875 ... 79.12 79.38 79.62 79.88
#   * xq          (xq) float64 0.25 0.5 0.75 1.0 1.25 ... 79.25 79.5 79.75 80.0
#   * yq          (yq) float64 -69.89 -69.81 -69.72 ... -30.35 -30.13 -29.92
#   * z_i         (z_i) float64 0.0 1.0 3.787 8.252 ... 3.798e+03 3.898e+03 4e+03
#   * yh          (yh) float64 -69.94 -69.85 -69.77 ... -30.46 -30.24 -30.02
#   * nv          (nv) float64 1.0 2.0
#   * z_l         (z_l) float64 0.5 2.393 6.02 ... 3.748e+03 3.848e+03 3.949e+03
#   * Time        (Time) float64 182.5 547.5 912.5 ... 6.752e+03 7.118e+03
# Data variables:
#     temp        (Time, z_l, yh, xh) float32 dask.array<chunksize=(10, 75, 272, 320), meta=np.ndarray>
#     salt        (Time, z_l, yh, xh) float32 dask.array<chunksize=(10, 75, 272, 320), meta=np.ndarray>
#     u           (Time, z_l, yh, xq) float32 dask.array<chunksize=(10, 75, 272, 320), meta=np.ndarray>
#     v           (Time, z_l, yq, xh) float32 dask.array<chunksize=(10, 75, 272, 320), meta=np.ndarray>
#     umo         (Time, z_l, yh, xq) float32 dask.array<chunksize=(10, 75, 272, 320), meta=np.ndarray>
#     vmo         (Time, z_l, yq, xh) float32 dask.array<chunksize=(10, 75, 272, 320), meta=np.ndarray>
#     average_T1  (Time) float64 dask.array<chunksize=(10,), meta=np.ndarray>
#     average_T2  (Time) float64 dask.array<chunksize=(10,), meta=np.ndarray>
#     average_DT  (Time) float64 dask.array<chunksize=(10,), meta=np.ndarray>
#     Time_bnds   (Time, nv) float64 dask.array<chunksize=(10, 2), meta=np.ndarray>
# Attributes:
#     filename:          prog_z.nc
#     title:             channel_4th-deg
#     associated_files:  area_t: grid.nc
#     grid_type:         regular
#     grid_tile:         N/A
# <xarray.Dataset>
# Dimensions:     (nv: 2, rho2_i: 36, rho2_l: 35, time: 20, xh: 320, xq: 320, yh: 272, yq: 272)
# Coordinates:
#   * xh          (xh) float64 0.125 0.375 0.625 0.875 ... 79.12 79.38 79.62 79.88
#   * xq          (xq) float64 0.25 0.5 0.75 1.0 1.25 ... 79.25 79.5 79.75 80.0
#   * yq          (yq) float64 -69.89 -69.81 -69.72 ... -30.35 -30.13 -29.92
#   * yh          (yh) float64 -69.94 -69.85 -69.77 ... -30.46 -30.24 -30.02
#   * rho2_i      (rho2_i) float64 999.5 1.028e+03 ... 1.037e+03 1.038e+03
#   * nv          (nv) float64 1.0 2.0
#   * rho2_l      (rho2_l) float64 1.014e+03 1.028e+03 ... 1.037e+03 1.038e+03
#   * time        (time) float64 182.5 547.5 912.5 ... 6.752e+03 7.118e+03
# Data variables:
#     temp        (time, rho2_l, yh, xh) float32 dask.array<chunksize=(10, 35, 272, 320), meta=np.ndarray>
#     salt        (time, rho2_l, yh, xh) float32 dask.array<chunksize=(10, 35, 272, 320), meta=np.ndarray>
#     u           (time, rho2_l, yh, xq) float32 dask.array<chunksize=(10, 35, 272, 320), meta=np.ndarray>
#     v           (time, rho2_l, yq, xh) float32 dask.array<chunksize=(10, 35, 272, 320), meta=np.ndarray>
#     umo         (time, rho2_l, yh, xq) float32 dask.array<chunksize=(10, 35, 272, 320), meta=np.ndarray>
#     vmo         (time, rho2_l, yq, xh) float32 dask.array<chunksize=(10, 35, 272, 320), meta=np.ndarray>
#     e           (time, rho2_i, yh, xh) float32 dask.array<chunksize=(10, 36, 272, 320), meta=np.ndarray>
#     h           (time, rho2_l, yh, xh) float32 dask.array<chunksize=(10, 35, 272, 320), meta=np.ndarray>
#     average_T1  (time) float64 dask.array<chunksize=(10,), meta=np.ndarray>
#     average_T2  (time) float64 dask.array<chunksize=(10,), meta=np.ndarray>
#     average_DT  (time) float64 dask.array<chunksize=(10,), meta=np.ndarray>
#     time_bnds   (time, nv) float64 dask.array<chunksize=(10, 2), meta=np.ndarray>
# Attributes:
#     filename:          prog_rho2.nc
#     title:             channel_4th-deg
#     associated_files:  area_t: grid.nc
#     grid_type:         regular
#     grid_tile:         N/A
# /home/Hemant.Khatri/anaconda3/envs/analysis_python3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: In xarray version 0.14 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   after removing the cwd from sys.path.
# /home/Hemant.Khatri/anaconda3/envs/analysis_python3/lib/python3.7/site-packages/xarray/backends/api.py:934: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,

# %%
dsgrid = xr.open_dataset(ppdir+"grid.nc", decode_times=False)
dsgrid = dsgrid.drop('Time')

ds_z = xr.merge([ds_z, dsgrid])
ds_rho = xr.merge([ds_rho, dsgrid])

# %%
grid = Grid(ds_z, coords={'X': {'center': 'xh', 'right': 'xq'},
                        'Y': {'center': 'yh', 'right': 'yq'},
                        'Z': {'center': 'zl', 'outer': 'zi'} }, periodic=['X']);

# %%
plt.figure(figsize=(20,6))

ct = 0
for i in range(4,20,10):
    plt.subplot(2,4,4*ct + 1)
    tmp = ds_z['u'].isel(Time = i, z_l=0)
    plt.pcolor(ds_z['xq'], ds_z['yh'], tmp, vmin = -0.5, vmax = 0.5, cmap='coolwarm')
    plt.colorbar(extend='both')
    plt.ylabel('Lat')
    if(ct>0):
        plt.xlabel('Lon')
    plt.title('Zonal Velocity, T = ' + str(i+1) + ' year')
    
    plt.subplot(2,4,4*ct + 2)
    tmp = ds_z['v'].isel(Time = i, z_l=0)
    plt.pcolor(ds_z['xh'], ds_z['yq'], tmp, vmin = -0.5, vmax = 0.5, cmap='coolwarm')
    plt.colorbar(extend='both')
    if(ct>0):
        plt.xlabel('Lon')
    plt.title('Meridional Velocity, T = ' + str(i + 1) + ' year')
    
    plt.subplot(2,4,4*ct + 3)
    tmp = ds_z['temp'].isel(Time = i, z_l=0)
    plt.pcolor(ds_z['xh'], ds_z['yh'], tmp)
    plt.colorbar(extend='both')
    if(ct>0):
        plt.xlabel('Lon')
    plt.title('Temperature, T = ' + str(i+1) + ' yer')
    
    plt.subplot(2,4,4*ct + 4)
    tmp = ds_z['salt'].isel(Time = i, z_l=0)
    plt.pcolor(ds_z['xh'], ds_z['yh'], tmp)
    plt.colorbar(extend='both')
    if(ct>0):
        plt.xlabel('Lon')
    plt.title('Salinity, T = ' + str(i+1) + ' year')
    
    ct = ct + 1

# %%
plt.figure(figsize=(18,6))

ct = 0
for i in range(4,20,10):
    plt.subplot(2,3,3*ct + 1)
    tmp = ds_z['u'].isel(Time = i, xq=120)
    plt.pcolor(ds_z['yh'], ds_z['z_l'], tmp, vmin = -0.5, vmax = 0.5, cmap='coolwarm')
    plt.colorbar(extend='both')
    plt.ylabel('Depth')
    if(ct>0):
        plt.xlabel('Lat')
    plt.title('Zonal Velocity, T = ' + str(i+1) + ' year')
    plt.gca().invert_yaxis()
    
    plt.subplot(2,3,3*ct + 2)
    tmp = ds_z['temp'].isel(Time = i, xh=120)
    plt.pcolor(ds_z['yh'], ds_z['z_l'], tmp)
    plt.colorbar(extend='both')
    if(ct>0):
        plt.xlabel('Lat')
    plt.title('Temperature, T = ' + str(i+1) + ' year')
    plt.gca().invert_yaxis()
    
    plt.subplot(2,3,3*ct + 3)
    tmp = ds_z['salt'].isel(Time = i, xh=120)
    plt.pcolor(ds_z['yh'], ds_z['z_l'], tmp)
    plt.colorbar(extend='both')
    if(ct>0):
        plt.xlabel('Lat')
    plt.title('Salt, T = ' + str(i+1) + ' year')
    plt.gca().invert_yaxis()
    
    ct = ct + 1

# %%
plt.figure(figsize=(18,6))

plt.subplot(1,4,1)
for i in range(0,20,5):
    tmp = ds_z['temp'].isel(Time=i).sel(yh=slice(-31.0, -30.0)).mean(['xh','yh'])
    plt.plot(tmp, ds_z['z_l'], label = str(i+1))
plt.grid()
plt.ylim((0,4000))
plt.gca().invert_yaxis()
plt.xlabel('Temperature (Deg C)')
plt.ylabel('Depth (m)')
plt.legend()
plt.title('30 S')

plt.subplot(1,4,2)
for i in range(0,20,5):
    tmp = ds_z['temp'].isel(Time=i).sel(yh=slice(-68.0, -67.0)).mean(['xh','yh'])
    plt.plot(tmp, ds_z['z_l'], label = str(i+1))
plt.grid()
plt.ylim((0,4000))
plt.gca().invert_yaxis()
plt.xlabel('Temperature (Deg C)')
plt.legend()
plt.title('67 S')

plt.subplot(1,4,3)
for i in range(0,20,5):
    tmp = ds_z['salt'].isel(Time=i).sel(yh=slice(-31.0, -30.0)).mean(['xh','yh'])
    plt.plot(tmp, ds_z['z_l'], label = str(i+1))
plt.grid()
plt.ylim((0,4000))
plt.gca().invert_yaxis()
plt.xlabel('Salinity (psu)')
plt.title('30 S')
plt.legend()

plt.subplot(1,4,4)
for i in range(0,20,5):
    tmp = ds_z['salt'].isel(Time=i).sel(yh=slice(-68.0, -67.0)).mean(['xh','yh'])
    plt.plot(tmp, ds_z['z_l'], label = str(i+1))
plt.grid()
plt.ylim((0,4000))
plt.gca().invert_yaxis()
plt.xlabel('Salinity (psu)')
plt.legend()
plt.title('67 S')
# Out:
# Text(0.5, 1.0, '67 S')

# %%
ds_rho.close()
ds_z.close()
client.close()
cluster.close()
